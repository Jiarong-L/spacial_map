# %% [markdown]
# 将'raw/expr_matrix_10day_log_normalized.txt'中每个cell取值都限制到0-1区间内

# %%
import numpy as np
import pandas as pd
import novosparc
import matplotlib
import matplotlib.pyplot as plt
from scipy.spatial.distance import cdist
# %matplotlib inline

# %%
line = [i*150 for i in range(50)]

# %%
plt.scatter(line, line, c=line, s=50)
